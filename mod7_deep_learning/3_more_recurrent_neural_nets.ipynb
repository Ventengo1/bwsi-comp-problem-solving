# %% [markdown]
# # Deep Learning: More Recurrent Neural Networks

# %%
# !pip install torchtext
import torch
import torch.nn as nn
import torchtext
from torchtext.data import Field, LabelField, BucketIterator
from torchtext.datasets import SST
from tqdm import tqdm
import matplotlib.pyplot as plt
torch.manual_seed(12)

print(f"Pytorch version: {torch.__version__}")
print(f"Torchtext version: {torchtext.__version__}")
# Out:
# Collecting torchtext
#   Downloading torchtext-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torchtext) (4.67.3)
# Collecting requests (from torchtext)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: torch in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torchtext) (2.11.0)
# Requirement already satisfied: numpy in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torchtext) (2.4.2)
# Requirement already satisfied: six in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torchtext) (1.17.0)
# Collecting sentencepiece (from torchtext)
#   Downloading sentencepiece-0.2.1-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting charset_normalizer<4,>=2 (from requests->torchtext)
#   Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests->torchtext)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests->torchtext)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests->torchtext)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torch->torchtext) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torch->torchtext) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torch->torchtext) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torch->torchtext) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torch->torchtext) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torch->torchtext) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from torch->torchtext) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from sympy>=1.13.3->torch->torchtext) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from jinja2->torch->torchtext) (3.0.3)
# Requirement already satisfied: colorama in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from tqdm->torchtext) (0.4.6)
# Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl (158 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading sentencepiece-0.2.1-cp313-cp313-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 7.4 MB/s  0:00:00
# Installing collected packages: urllib3, sentencepiece, idna, charset_normalizer, certifi, requests, torchtext
#
#    ---------------------------------------- 0/7 [urllib3]
#    ---------------------------------------- 0/7 [urllib3]
#    ---------------------------------------- 0/7 [urllib3]
#    ---------------------------------------- 0/7 [urllib3]
#    ----- ---------------------------------- 1/7 [sentencepiece]
#    ----------- ---------------------------- 2/7 [idna]
#    ----------------- ---------------------- 3/7 [charset_normalizer]
#    ----------------- ---------------------- 3/7 [charset_normalizer]
#    ---------------------------- ----------- 5/7 [requests]
#    ---------------------------- ----------- 5/7 [requests]
#    ---------------------------------- ----- 6/7 [torchtext]
#    ---------------------------------- ----- 6/7 [torchtext]
#    ---------------------------------- ----- 6/7 [torchtext]
#    ---------------------------------- ----- 6/7 [torchtext]
#    ---------------------------------------- 7/7 [torchtext]
#
# Successfully installed certifi-2026.4.22 charset_normalizer-3.4.7 idna-3.13 requests-2.33.1 sentencepiece-0.2.1 torchtext-0.6.0 urllib3-2.6.3
# Pytorch version: 2.11.0+cpu
# Torchtext version: 0.6.0

# %% [markdown]
# ### Note: Python must be 3.11.x
#
# If your kernel shows a value > 3.11.x you will need to downgrade. Please email the staff for help

# %%
# DEVICE CONFIGURATION
if torch.backends.mps.is_available():          # Apple Silicon
    device = torch.device("mps")
elif torch.cuda.is_available():                # CUDA GPU
    device = torch.device("cuda")
else:
    device = torch.device("cpu")               # Fallback

print("Using device:", device)
# Out:
# Using device: cpu

# %%
# Define field types
TEXT = Field(tokenize='basic_english', lower=True, include_lengths=True)
LABEL = LabelField(dtype=torch.float)

# !pip install nltk

# Load SST data
train_data, _, test_data = SST.splits(
    TEXT, LABEL, fine_grained=False
)
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\Users\ojas\Downloads\bwsi-comp-problem-solving\.venv\Lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 9.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.4 MB/s  0:00:00
# Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl (277 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Installing collected packages: regex, click, nltk
#
#    ---------------------------------------- 0/3 [regex]
#    ---------------------------------------- 0/3 [regex]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed click-8.3.3 nltk-3.9.4 regex-2026.4.4

# %%
# Display size of datasets
print("Train size:", len(train_data))
print("Test size:", len(test_data))
# Out:
# Train size: 8544
# Test size: 2210

# %% [markdown]
# The `.splits` method is splitting up our dataset so that our train and test sets both have representative samples.
#
# The `fine_grained` parameter determines how many categories our data is broken into.
# - if `True`: labels can be {'positive': 0, 'negative': 1, 'neutral': 2, 'very positive': 3, 'very negative': 4}
# - if `False`: labels can be {'positive': 0, 'negative': 1, 'neutral': 2}

# %%
# Build vocabulary
MAX_VOCAB_SIZE = 10000
TEXT.build_vocab(train_data, max_size=MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

vocab = TEXT.vocab.stoi
pad_idx = TEXT.vocab.stoi[TEXT.pad_token]

# %% [markdown]
# ### Q: What variable type is `vocab`? What does the `.build_vocab` method do?
# Hint: `.stoi` stand for "string to int"!

# %% [markdown]
# ### A:
# Vocab is an integer. .build_vocab builds this integer by adding data to it.

# %%
def decode_dataset(dataset):
    # Reverse label mapping: string -> int
    label_stoi = LABEL.vocab.stoi
    texts = [example.text for example in dataset] 
    labels = [label_stoi[example.label] for example in dataset]
    return texts, labels

train_texts, train_labels = decode_dataset(train_data)
test_texts, test_labels   = decode_dataset(test_data)

# %% [markdown]
# ### Sanity Check 🧠
# Let's check that the decoded dataset makes sense!

# %%
label_map = {idx: word for word, idx in LABEL.vocab.stoi.items()}

# Change i and see what happens!
i = 4

print(" ".join(test_texts[i]))
print(label_map[test_labels[i]])
# Out:
# offers that rare combination of entertainment and education .
# positive

# %% [markdown]
# ----

# %% [markdown]
# Now let's define a `BucketIterator`:

# %%
BATCH_SIZE = 32
train_iterator, test_iterator = BucketIterator.splits(
    (train_data, test_data),
    batch_size=BATCH_SIZE,
    sort_within_batch=True,
    sort_key=lambda x: len(x.text),
    device=device
)

# %% [markdown]
# Below is a custom classifier:

# %%
# Custom LSTM Classifier
class SimpleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=pad_idx)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=False)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, text, text_lengths):
        # text: [batch_size, seq_len] if batch_first=True
        embedded = self.embedding(text)  # [batch_size, seq_len, emb_dim]

        # Pack padded sequence
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths.cpu(), batch_first=False, enforce_sorted=False)
        packed_output, (hidden, cell) = self.lstm(packed_embedded)

        # hidden: [1, batch_size, hidden_dim]  -> take the last hidden state
        return self.fc(hidden.squeeze(0))  # [batch_size, output_dim]

# %% [markdown]
# Here's a helper function so we can vary parameters later:

# %%
# TRAINING LOOP FUNCTION
def run_training_loop(num_epochs, random_state):
    # set random seed
    torch.manual_seed(random_state)

    EMBEDDING_DIM = 100
    HIDDEN_DIM = 256
    OUTPUT_DIM = 1

    # Send model to device
    model = SimpleLSTM(len(vocab), EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, pad_idx).to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # init output vars
    train_losses = []
    train_accs = []

    # train for num_epochs
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        epoch_acc = 0

        # Wrap the iterator with tqdm
        for batch in tqdm(train_iterator, desc=f"Epoch {epoch+1}/{num_epochs}"):
            text, text_lengths = batch.text
            labels = batch.label

            text, text_lengths, labels = text.to(device), text_lengths.to(device), labels.to(device)

            optimizer.zero_grad()
            predictions = model(text, text_lengths).squeeze(1)

            # Loss
            loss = criterion(predictions, labels.float())
            loss.backward()
            optimizer.step()

            # Optional: compute accuracy
            preds = torch.round(torch.sigmoid(predictions))
            acc = (preds == labels).float().mean()
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
        avg_loss = epoch_loss/ len(train_iterator)
        avg_acc = epoch_acc/ len(train_iterator)
        train_losses.append(avg_loss)
        train_accs.append(avg_acc)
        print(f"Loss = {avg_loss:.4f}, Accuracy = {avg_acc:.4f}\n")
    return train_losses, train_accs, model

# %% [markdown]
# And another helper function plot the `train_losses` and `train_accs`:

# %%
def plot_training_performance(train_losses, train_accs, num_epochs, random_state):
    fig = plt.figure(figsize=(8,4), tight_layout=True)
    fig.suptitle(f"Model Training for State {random_state} over {num_epochs} Epochs")

    plt.subplot(1,2,1)
    plt.plot(train_losses, "-o", label="Train Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(train_accs, "-o", label="Train Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.grid()
    plt.legend()
    plt.show()

# %% [markdown]
# Let's train our model!

# %%
NUM_EPOCHS = 10
RANDOM_STATE = 10
find_grained = True
train_losses, train_accs, model = run_training_loop(NUM_EPOCHS, RANDOM_STATE)
# Out:
# Epoch 1/10: 100%|██████████| 267/267 [00:12<00:00, 21.90it/s]
# Loss = 0.5403, Accuracy = 0.3912
# Epoch 2/10: 100%|██████████| 267/267 [00:17<00:00, 15.52it/s]
# Loss = 0.4913, Accuracy = 0.4032
# Epoch 3/10: 100%|██████████| 267/267 [00:16<00:00, 16.40it/s]
# Loss = 0.3585, Accuracy = 0.4819
# Epoch 4/10: 100%|██████████| 267/267 [00:14<00:00, 17.91it/s]
# Loss = 0.0099, Accuracy = 0.5320
# Epoch 5/10: 100%|██████████| 267/267 [00:20<00:00, 13.08it/s]
# Loss = -1.5045, Accuracy = 0.5658
# Epoch 6/10: 100%|██████████| 267/267 [00:23<00:00, 11.50it/s]
# Loss = -5.1614, Accuracy = 0.5934
# Epoch 7/10: 100%|██████████| 267/267 [00:23<00:00, 11.48it/s]
# Loss = -13.7502, Accuracy = 0.6300
# Epoch 8/10: 100%|██████████| 267/267 [00:21<00:00, 12.35it/s]
# Loss = -24.3741, Accuracy = 0.6515
# Epoch 9/10: 100%|██████████| 267/267 [00:22<00:00, 11.81it/s]
# Loss = -35.9402, Accuracy = 0.6615
# Epoch 10/10: 100%|██████████| 267/267 [00:22<00:00, 11.68it/s]
# Loss = -46.7168, Accuracy = 0.6717

# %%
plot_training_performance(train_losses, train_accs, NUM_EPOCHS, RANDOM_STATE)

# %% [markdown]
# ### Q: Try changing the value of `NUM_EPOCHS`. What happens to the train loss and accuracy plots? What does this tell us about the optimal number of training epochs?

# %% [markdown]
# ### A:
# As I increase the number of epcohs and accuracy increases and the training loss decreases. However, at a certain point the amount of effect made is pretty minmal. I think this tells us that the optimal number of trianing epochs is pretty high,

# %% [markdown]
# ### Q: Try changing the value of `RANDOM_STATE`. What happens to the train loss and accuracy plots? What does this tell us about the impact of the initial guess (i.e. epoch 0)?

# %% [markdown]
# ### A:
# Highering the random state to 75 lead the intiial guess to be pretty much the same. However lowering it to 20 led to the intitial guess being also the same. This means that there is not a huge impact.

# %% [markdown]
# ----

# %% [markdown]
# ## Performance on the Test Set

# %% [markdown]
# Here's a helper function to run our model on the test data:

# %%
# Evaluate on test set
def run_evaluation_test():
    model.eval()
    test_loss, test_acc, = 0,0

    with torch.no_grad():
        for batch in test_iterator:
            text, text_lengths = batch.text
            labels = batch.label

            text = text.to(device)
            text_lengths = text_lengths.to(device)
            labels = labels.to(device)

            criterion = nn.BCEWithLogitsLoss()
            predictions = model(text, text_lengths).squeeze(1)
            loss = criterion(predictions, labels.float())

            preds = torch.round(torch.sigmoid(predictions))
            acc = (preds == labels).float().mean()

            test_loss += loss.item()
            test_acc += acc.item()

    return print(f"Test Accuracy: {100 * test_acc / len(test_iterator):.2f}%")

# %% [markdown]
# Finally, let's check that our model can generalize by processing the test data:

# %%
run_evaluation_test()
# Out:
# Test Accuracy: 60.04%

# %% [markdown]
# ----
# ## Further Exploration 🔎

# %% [markdown]
# ### Q: What happens to the **test** accuracy as `NUM_EPOCHS` is changed? What does this tell us about our neural network?
# Note: remember to re-train your model before running on the test set!

# %% [markdown]
# ### A:
# As the number of epochs decreases the test accuracy decreases and as the number of epochs increases, it increases. This tells us that our neural network gets better as it is trained more.

# %% [markdown]
# ### Q: What happens to the **test** accuracy as `RANDOM_STATE` is changed? What does this tell us about our neural network?
# Note: remember to re-train your model before running on the test set!

# %% [markdown]
# ### A:
# As random state is changed, test accuracy changed too. This tells us that our neural netowrk is dependend on this too.

# %% [markdown]
# ### Q: What happens to your results if you set `find_grained=True`?
# Try to predict first and then test your hypothesis by changing the value and re-running the notebook!

# %% [markdown]
# ### A:
